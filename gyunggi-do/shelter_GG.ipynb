# %% [markdown]
# # 지진해일대피소 현황 분석 및 개선 방안 제시

# %%
import pandas as pd 
import folium 
import matplotlib
import matplotlib.pyplot as plt
import pylab
import numpy as np

#설치 안된거는 설치해주세요

# %%
# 파이그래프에서 한국어 나오게 하는 코드 

import matplotlib.font_manager as fm

for font in fm.fontManager.ttflist:
    if font.name in ['AppleGothic', 'Malgun Gothic']:
        plt.rcParams['font.family'] = font.name
        break

plt.rcParams['font.family']
# Out:
# ['Malgun Gothic']

# %% [markdown]
# # 선택한  데이터
# - 전국지진해일대피소표준데이터
#     - 통합, 광명시
# - KOSIS 행정구역(시군구)별 인구 통계 데이터

# %% [markdown]
# # EDA

# %% [markdown]
# ## 서울특별시, 인천광역시, 경기도 데이터만 추출
# ### 특이사항
# - 소재지도로명주소와 소재지지번주소 둘 중 하나만 기입되어 도로명 주소 결측치는 소재지지번주소 컬럼에서 가져옴
# - 경기도 광명시 데이터가 몇일 전에 올라와서 따로 다운받아 전국 통합본에 합침
#
# ### 과정
# 1. 주소를 string type으로 변환
# 2. 띄어쓰기를 기준으로 첫번째 덩어리 ('서울특별시', '인천광역시', '경기도' 등등)만 'area' 컬럼으로 저장
# 3. area가 '서울특별시', '인천광역시', '경기도'인건만 새로운 테이블(shelter_GG)로 저장

# %%
shelter = pd.read_csv('통합본(1015기준).csv')

# %%
# len(shelter)

# %%
# kwangmyung = pd.read_csv('경기도_광명시_지진해일대피소_20190909.csv', encoding = "CP949")

# %%
# len(kwangmyung)

# %%
# pd.DataFrame(kwangmyung.isnull().sum())

# %%
# kwangmyung['제공기관명'] = '경기도 광명시'

# %%
# dongdaemoon = pd.read_csv('dongdaemoon.csv') # 동대문구 위도, 경도 결측치 채워서 만든 csv

# %%
# dongdaemoon = pd.read_csv('서울특별시_동대문구_지진해일대피소_20190930.csv', encoding = "CP949")

# %%
# pd.DataFrame(dongdaemoon.isnull().sum())

# %%
# dongdaemoon['제공기관명'] = '서울특별시 동대문구'

# %%
# from geocoder import geocode

# %%
# lats = []
# lngs = []

# for i, index in enumerate(dongdaemoon.index):
#     print(i + 1, '-', index)
#     lat, lng = geocode(dongdaemoon['소재지도로명주소'][index])
#     lats.append(lat)
#     lngs.append(lng)

# dongdaemoon = dongdaemoon.assign(위도=lats, 경도=lngs)

# dongdaemoon.head()

# %%
# dongdaemoon.loc[0, 6:8] = ['37.5760811', '127.0289663']

# %%
# dongdaemoon.loc[20, 6:8] = ['37.574318', '127.0422342']

# %%
# dongdaemoon.to_csv('dongdaemoon.csv')

# %%
# sungbuk = pd.read_csv('서울특별시_성북구_지진해일대피소_20190612.csv', encoding = "CP949")

# %%
# pd.DataFrame(sungbuk.isnull().sum())

# %%
# sungbuk['제공기관명'] = '서울특별시 성북구'

# %%
# shelter = pd.concat([shelter, kwangmyung, dongdaemoon, sungbuk], ignore_index = True, sort = False)

# %%
# shelter.to_csv('통합본(1015기준).csv')

# %%
len(shelter)
# Out:
# 10099

# %%
shelter.columns
# Out:
# Index(['Unnamed: 0', '지진해일대피소명', '지진해일대피소구분', '지진해일대피소유형', '지진해일대피소유형구분',
#        '소재지도로명주소', '소재지지번주소', '위도', '경도', '수용가능면적', '최대수용인원수', '지진해일대피소운영상태',
#        '지진해일대피소전화번호', '부대편의시설', '주민대피지구명', '주민대피지구내가구수', '주민대피지구내거주인수',
#        '주민대피지구내재해약자수', '내진적용여부', '내진설계등급', '해안선이격거리', '해발높이', '지진대피안내표지판수',
#        '긴급대피장소안내표지판수', '지진대피로안내표지판수', '관리기관명', '관리기관전화번호', '데이터기준일자', '제공기관코드',
#        '제공기관명', 'Unnamed: 29', 'Unnamed: 0.1', 'area'],
#       dtype='object')

# %% [markdown]
# # 위도 경도 결측치 채우기
#
# 1. 위도, 경도 결측치인 행만 빼서 하나의 테이블(nulls)로 저장
#     - 정해진 API이용횟수 때문
# 2. KAKAO API와 LOCATIONIQ API 활용해서 위도 경도 찾음
# 3. 두 API로도 안나온 주소지는 손수 찾아서 채움
# 4. 본래 통합본에 결측치 테이블(nulls) LEFT JOIN해서 최종 테이블(shelter_G)로 저장
# 5. 위도, 경도 결측치 남은 것 없는지 확인

# %%
shelter[shelter['소재지도로명주소'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, 지진해일대피소명, 지진해일대피소구분, 지진해일대피소유형, 지진해일대피소유형구분, 소재지도로명주소, 소재지지번주소, 위도, 경도, 수용가능면적, 최대수용인원수, 지진해일대피소운영상태, 지진해일대피소전화번호, 부대편의시설, 주민대피지구명, 주민대피지구내가구수, 주민대피지구내거주인수, 주민대피지구내재해약자수, 내진적용여부, 내진설계등급, 해안선이격거리, 해발높이, 지진대피안내표지판수, 긴급대피장소안내표지판수, 지진대피로안내표지판수, 관리기관명, 관리기관전화번호, 데이터기준일자, 제공기관코드, 제공기관명, Unnamed: 29, Unnamed: 0.1, area]
# Index: []
#
# [0 rows x 33 columns]

# %%
len(shelter[shelter['소재지도로명주소'].isnull()])
# Out:
# 0

# %%
len(shelter[shelter['소재지도로명주소'].isnull()&shelter['소재지지번주소'].isnull()])
# Out:
# 0

# %%
shelter[shelter['소재지도로명주소'].isnull()].head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, 지진해일대피소명, 지진해일대피소구분, 지진해일대피소유형, 지진해일대피소유형구분, 소재지도로명주소, 소재지지번주소, 위도, 경도, 수용가능면적, 최대수용인원수, 지진해일대피소운영상태, 지진해일대피소전화번호, 부대편의시설, 주민대피지구명, 주민대피지구내가구수, 주민대피지구내거주인수, 주민대피지구내재해약자수, 내진적용여부, 내진설계등급, 해안선이격거리, 해발높이, 지진대피안내표지판수, 긴급대피장소안내표지판수, 지진대피로안내표지판수, 관리기관명, 관리기관전화번호, 데이터기준일자, 제공기관코드, 제공기관명, Unnamed: 29, Unnamed: 0.1, area]
# Index: []
#
# [0 rows x 33 columns]

# %%
shelter['소재지도로명주소'] = shelter['소재지도로명주소'].fillna(shelter['소재지지번주소'])

# %%
shelter[shelter['소재지도로명주소'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, 지진해일대피소명, 지진해일대피소구분, 지진해일대피소유형, 지진해일대피소유형구분, 소재지도로명주소, 소재지지번주소, 위도, 경도, 수용가능면적, 최대수용인원수, 지진해일대피소운영상태, 지진해일대피소전화번호, 부대편의시설, 주민대피지구명, 주민대피지구내가구수, 주민대피지구내거주인수, 주민대피지구내재해약자수, 내진적용여부, 내진설계등급, 해안선이격거리, 해발높이, 지진대피안내표지판수, 긴급대피장소안내표지판수, 지진대피로안내표지판수, 관리기관명, 관리기관전화번호, 데이터기준일자, 제공기관코드, 제공기관명, Unnamed: 29, Unnamed: 0.1, area]
# Index: []
#
# [0 rows x 33 columns]

# %%
shelter['소재지도로명주소'][1103]
# Out:
# '경기도 양평군 강하면 운심리 57번지'

# %%
# 소재지도로명주소 string타입으로 변형 
shelter['소재지도로명주소'] = shelter['소재지도로명주소'].astype('str')

# %%
# 소재지도로명 띄어쓰기 기준으로 잘라 첫번째 덩어리만 area 컬럼에 저장
shelter['area'] = shelter['소재지도로명주소'].str.split(' ').str[0]

# %%
shelter.head()
# Out:
#    Unnamed: 0  지진해일대피소명 지진해일대피소구분 지진해일대피소유형 지진해일대피소유형구분             소재지도로명주소  \
# 0           0   내수2근린공원     지진대피소     옥외대피소          공원      서울특별시 종로구 경희궁4길
# 1           1  대동세무고등학교     지진대피소     옥외대피소         운동장  서울특별시 종로구 계동길 84-10
# 2           2    대신고등학교     지진대피소     옥외대피소         운동장      서울특별시 종로구 사직로 9
# 3           3  덕성여자고등학교     지진대피소     옥외대피소         운동장   서울특별시 종로구 율곡로3길 50
# 4           4   덕성여자중학교     지진대피소     옥외대피소         운동장   서울특별시 종로구 율곡로3길 49
#
#               소재지지번주소         위도          경도  수용가능면적  ...  긴급대피장소안내표지판수  \
# 0  서울특별시 종로구 내수동 73-3  37.572387  126.971583  2192.0  ...           NaN
# 1                 NaN  37.581920  126.987930  2000.0  ...           NaN
# 2                 NaN  37.572915  126.961601  4663.0  ...           NaN
# 3                 NaN  37.577918  126.982867  4180.0  ...           NaN
# 4                 NaN  37.577945  126.981778  6701.0  ...           NaN
#
#   지진대피로안내표지판수 관리기관명      관리기관전화번호     데이터기준일자     제공기관코드      제공기관명  \
# 0         NaN  종로구청  02-2148-2483  2018-08-14  3000000.0  서울특별시 종로구
# 1         NaN  종로구청  02-2148-2483  2018-08-14  3000000.0  서울특별시 종로구
# 2         NaN  종로구청  02-2148-2483  2018-08-14  3000000.0  서울특별시 종로구
# 3         NaN  종로구청  02-2148-2483  2018-08-14  3000000.0  서울특별시 종로구
# 4         NaN  종로구청  02-2148-2483  2018-08-14  3000000.0  서울특별시 종로구
#
#    Unnamed: 29 Unnamed: 0.1   area
# 0          NaN          NaN  서울특별시
# 1          NaN          NaN  서울특별시
# 2          NaN          NaN  서울특별시
# 3          NaN          NaN  서울특별시
# 4          NaN          NaN  서울특별시
#
# [5 rows x 33 columns]

# %%
shelter.area.unique()
# Out:
# array(['서울특별시', '대전광역시', '충청북도', '경기도', '인천광역시', '경상남도', '강원도', '전라북도',
#        '광주광역시', '경상북도', '충청남도', '부산광역시', '대구광역시', '전라남도', '울산광역시',
#        '제주특별자치도', '세종특별자치시'], dtype=object)

# %%
shelter_GG = shelter[(shelter['area']=='서울특별시')|(shelter['area']=='인천광역시')|(shelter['area']=='경기도')]

# %%
shelter_GG.area.unique()
# Out:
# array(['서울특별시', '경기도', '인천광역시'], dtype=object)

# %%
len(shelter_GG)
# Out:
# 3386

# %%
# 컬럼별 null값 찾기
data = shelter_GG.isnull().sum()
pd.DataFrame(data)
# Out:
#                  0
# Unnamed: 0       0
# 지진해일대피소명         0
# 지진해일대피소구분        0
# 지진해일대피소유형        0
# 지진해일대피소유형구분      0
# 소재지도로명주소         0
# 소재지지번주소       2201
# 위도              71
# 경도              70
# 수용가능면적           0
# 최대수용인원수          0
# 지진해일대피소운영상태      0
# 지진해일대피소전화번호      0
# 부대편의시설        3301
# 주민대피지구명          0
# 주민대피지구내가구수    3276
# 주민대피지구내거주인수   3356
# 주민대피지구내재해약자수  3356
# 내진적용여부           0
# 내진설계등급        3367
# 해안선이격거리       3386
# 해발높이          3373
# 지진대피안내표지판수    2362
# 긴급대피장소안내표지판수  3346
# 지진대피로안내표지판수   3334
# 관리기관명            0
# 관리기관전화번호      1283
# 데이터기준일자          0
# 제공기관코드         231
# 제공기관명            0
# Unnamed: 29   3386
# Unnamed: 0.1  3335
# area             0

# %%
# nulls = shelter_GG[shelter_GG['위도'].isnull()]

# %%
# d= {'a': '백제고분로39길'}
# test = pd.DataFrame(list(d.items()), columns=['alphabet', 'address'])
# test

# %%
# test.index

# %%
# from geocoder import geocode

# %%
# from geocoder import geocode

# full_ad = []

# for i, index in enumerate(test.index):
#     print(i + 1, '-', index)
#     address_name = geocode(test['address'][index])
#     full_ad.append(address_name)
    
# test = test.assign(full=full_ad)

# %%
# lats = []
# lngs = []

# for i, index in enumerate(nulls.index):
#     print(i + 1, '-', index)
#     lat, lng = geocode(nulls['소재지도로명주소'][index])
#     lats.append(lat)
#     lngs.append(lng)

# nulls = nulls.assign(lat=lats, lng=lngs)

# nulls.head()

# %%
# nulls.to_csv('nulls.csv')

# %%
# import os
# import requests

# %%
# LOCATIONIQ_TOKEN = os.environ['LOCATIONIQ_TOKEN']

# %%
# def gc(address):
#     url = 'https://us1.locationiq.com/v1/search.php'
#     payload = {
#         'key': LOCATIONIQ_TOKEN,
#         'q': address,
#         'format': 'json'
#     }
#     response = requests.get(url, params=payload)
#     results = response.json()
#     if 'error' in results:
#         return None, None
#     coordinates = results[0]
#     return coordinates['lat'], coordinates['lon']

# %%
# lats = []
# lngs = []

# for i, index in enumerate(nulls.index):
#     print(i + 1, '-', index)
#     lat, lng = gc(nulls['소재지도로명주소'][index])
#     lats.append(lat or 0)
#     lngs.append(lng or 0)

# nulls = nulls.assign(위=lats, 경=lngs)

# nulls.head()

# %%
nulls = pd.read_csv('nulls.csv')

# %%
nulls.head()
# Out:
#         지진해일대피소명          위           경
# 0         계양교통공원  37.108100  129.003000
# 1        해뜰어린이공원  37.655230  126.625070
# 2        도림동 유수지  37.504137  126.895320
# 3  안양천 영롱이 인라인마당  37.512453  126.912734
# 4   안양천 억새구장 축구장  37.512453  126.912734

# %%
shelter_G = shelter_GG.merge(nulls, how='left', on='지진해일대피소명')

# %%
len(shelter_G) #merge 잘 됐는지 확인 완료
# Out:
# 3386

# %%
 #nulls 테이블에 있던 위도 경도 shelter_GG 테이블 위도 경도로 옮기기
shelter_G['위도'] = shelter_G['위도'].fillna(shelter_G['위'])

# %%
shelter_G['경도'] = shelter_G['경도'].fillna(shelter_G['경'])

# %%
pd.DataFrame(shelter_G.isnull().sum()) #위도, 경도 결측치 다 채운 것 확인완료
# Out:
#                  0
# Unnamed: 0       0
# 지진해일대피소명         0
# 지진해일대피소구분        0
# 지진해일대피소유형        0
# 지진해일대피소유형구분      0
# 소재지도로명주소         0
# 소재지지번주소       2201
# 위도               0
# 경도               0
# 수용가능면적           0
# 최대수용인원수          0
# 지진해일대피소운영상태      0
# 지진해일대피소전화번호      0
# 부대편의시설        3301
# 주민대피지구명          0
# 주민대피지구내가구수    3276
# 주민대피지구내거주인수   3356
# 주민대피지구내재해약자수  3356
# 내진적용여부           0
# 내진설계등급        3367
# 해안선이격거리       3386
# 해발높이          3373
# 지진대피안내표지판수    2362
# 긴급대피장소안내표지판수  3346
# 지진대피로안내표지판수   3334
# 관리기관명            0
# 관리기관전화번호      1283
# 데이터기준일자          0
# 제공기관코드         231
# 제공기관명            0
# Unnamed: 29   3386
# Unnamed: 0.1  3335
# area             0
# 위             3313
# 경             3313

# %% [markdown]
# # 분석 시작

# %% [markdown]
# ## 1. 지진해일대피소유형 분석
# - 옥외대피소 vs 실내대피소

# %%
shelter_GG['지진해일대피소유형'].unique()
# Out:
# array(['옥외대피소', '실내대피소'], dtype=object)

# %%
labels=['옥외대피소', '실내대피소']
shelter_GG['지진해일대피소유형'].value_counts().plot.pie(labels = labels
                    ,colors= ['#98DBC6', '#FFCCBB']
                    ,startangle = 60
                    ,shadow = True
                    ,autopct = '%1.1f%%'
                    ,explode = (0,0.1) 
                    ,figsize=(5, 5)
                    ,fontsize = 15)
plt.title('경기도 지진해일대피소구분', fontsize=20)
pylab.ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ## 2. 내진설계 분석
# - 실내 대피소 중 내질설계가 되어있는 대피소는 얼마나 될까?

# %%
for_seismic = shelter_G[shelter_G['지진해일대피소유형']=='실내대피소']

# 실내 대피소만 내진설계가 가능하기 때문에 실내 대피소만

# %%
seismic_design = len(for_seismic[for_seismic['내진적용여부']=='적용'])/len(for_seismic)*100
print('경인, 경기지역 내진설계 비율 =', seismic_design, '%')
# Out:
# 경인, 경기지역 내진설계 비율 = 78.57142857142857 %

# %%
labels=['적용', '미적용']   #항상 파이그래프 보면서 label순서 제대로 설정했는지 확인 
for_seismic['내진적용여부'].value_counts().plot.pie(labels = labels
                    ,colors= ['#98DBC6', '#FFCCBB'] #색깔 지정 (색깔 코드 인터넷 검색)
                    ,startangle = 60                #시작 각도 설정
                    ,shadow = True                  #그림자 생성
                    ,autopct = '%1.1f%%'            # 퍼센테이지 소숫점 설정
                    ,explode = (0,0.1)              # 한 파트 톡 튀어 나오게 만들기 (꼭 파트의 수와 동일해야함 안그럼 오류 EG)4개로 구분되면 (0, 0, 0, 0.1)로 기재)
                    ,figsize=(5, 5)                 # 그래프 사이즈 설정 
                    ,fontsize = 15)                 # 글씨 크기 설정
plt.title('경기도 실내 지진해일대피소 내진적용여부', fontsize=20)   #제목명, 제목 사이즈 설정
pylab.ylabel('')    # y축 설명 없애기
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ![](bk3)

# %% [markdown]
# ### 배경지식
# - 실외대피소: 지진 또는 해일이 발생할 경우 실외대피소에서 집합 후 안내 방송에 따라 다같이 이동하기 위한 용도
# - 실내대피소: 집합 또는 이재민 수용을 위한 임시주거시설로 이용

# %% [markdown]
# ![](bk3.png)

# %%
labels=['적용', '미적용']
for_seismic[(for_seismic['지진해일대피소유형구분']=='학교')|(['지진해일대피소유형구분']=='체육관')]['내진적용여부'].value_counts().plot.pie(labels = labels
                    ,colors= ['#98DBC6', '#FFCCBB'] #색깔 지정 (색깔 코드 인터넷 검색)
                    ,startangle = 60                #시작 각도 설정
                    ,shadow = True                  #그림자 생성
                    ,autopct = '%1.1f%%'            # 퍼센테이지 소숫점 설정
                    ,explode = (0,0.1)              # 한 파트 톡 튀어 나오게 만들기 (꼭 파트의 수와 동일해야함 안그럼 오류 EG)4개로 구분되면 (0, 0, 0, 0.1)로 기재)
                    ,figsize=(5, 5)                 # 그래프 사이즈 설정 
                    ,fontsize = 15)                 # 글씨 크기 설정
plt.title('학교, 체육관 지진해일대피소 내진적용여부', fontsize=20)   #제목명, 제목 사이즈 설정
pylab.ylabel('')    # y축 설명 없애기
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ## 2. 지진해일 대피소 구분 분석
# - 지진해일대피소 vs 지진대피소

# %%
len(shelter_G[shelter_G['지진해일대피소구분']=='지진대피소'])
# Out:
# 3353

# %%
labels=['지진대피소', '지진해일대피소']
shelter_G['지진해일대피소구분'].value_counts().plot.pie(labels = labels
                    ,colors= ['#98DBC6', '#FFCCBB']
                    ,startangle = 60
                    ,shadow = True
                    ,autopct = '%1.1f%%'
                    ,explode = (0,0.1) 
                    ,figsize=(5, 5)
                    ,fontsize = 15)
plt.title('경기도 지진해일대피소구분', fontsize=20)
pylab.ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ## 4. 지진해일대피소유형구분 분석

# %%
shelter_G['지진해일대피소유형구분'].unique()
# Out:
# array(['공원', '운동장', '학교', '기타', '체육관'], dtype=object)

# %%
labels=['공원', '운동장', '학교', '기타', '체육관']
shelter_G['지진해일대피소유형구분'].value_counts().plot.pie(labels = labels
                    ,colors= ['#98DBC6','#5BC8AC','#E6D72A','#F18D9E', '#FFCCBB']
                    ,startangle = 60
                    ,shadow = True
                    ,autopct = '%1.1f%%'
                    ,explode = (0.1,0,0,0,0) 
                    ,figsize=(5, 5)
                    ,fontsize = 15)
plt.title('경기도 지진해일대피소유형구분', fontsize=20)
pylab.ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ## 5. 지진해일대피소운영상태 분석

# %%
shelter_G['지진해일대피소운영상태'].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
labels=['운영중', '비운영중']
shelter_G['지진해일대피소운영상태'].value_counts().plot.pie(labels = labels
                    ,colors= ['#98DBC6', '#FFCCBB']
                    ,startangle = 60
                    ,shadow = True
                    ,autopct = '%1.1f%%'
                    ,explode = (0.1,0) 
                    ,figsize=(5, 5)
                    ,fontsize = 15)
plt.title('경기도 지진해일대피소운영상태', fontsize=20)
pylab.ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ## 6. 지역별 대피소 수

# %%
shelter_G['area'].unique()
# Out:
# array(['서울특별시', '경기도', '인천광역시'], dtype=object)

# %%
labels=['서울특별시', '경기도', '인천광역시']
shelter_G['area'].value_counts().plot.pie(labels = labels
                    ,colors= ['#98DBC6','#F18D9E', '#FFCCBB']
                    ,startangle = 60
                    ,shadow = True
                    ,autopct = '%1.1f%%' 
                    ,explode = (0.1,0, 0) 
                    ,figsize=(5, 5)
                    ,fontsize = 15)
plt.title('경기도 지진해일대피소운영상태', fontsize=20)
pylab.ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ## 7. 지역별 대피소 지도 만들기
# - 처음에는 전국 데이터를 한번에 찍어보려 했으나 데이터가 너무 많아 지도가 뜨지 않음
# - 8도로 나누어 시도 -> 서울, 인천, 경기 3곳 모두 데이터 양이 많아 지도 안뜸
#     - 데이터 양의 문제가 아니였음
#     - 타일 옵션인 Mapbox Bright가 더이상 지원되지 않아서 생겼던 문제

# %% [markdown]
# ### 경도, 위도 입력 잘못되어 있는 곳
# - 계양교통공원
# - 서울용곡중학교 (실내, 실외)
# - 대방공원

# %% [markdown]
# ## 경도, 위도 잘못 입력된 곳 정보 수정

# %%
# 계양교통공원 정보 수정
shelter_G.iloc[136, 6] = 37.5372564
shelter_G.iloc[136, 7] = 126.7418268

# %%
# 서울용곡중학교 정보 수정
shelter_G.iloc[1620, 6] = 37.5660646
shelter_G.iloc[1620, 7] = 127.0866867

shelter_G.iloc[1632, 6] = 37.5660646
shelter_G.iloc[1632, 7] = 127.0866867

# %%
# 대방공원 정보 수정 
shelter_G.iloc[239, 6] = 37.5100726
shelter_G.iloc[239, 7] = 126.9264025

# %% [markdown]
# ## 서울 지도

# %%
shelter_incheon = shelter_G[shelter_G['area']=='서울특별시']
map = folium.Map(location=[37.5650172, 126.849465], zoom_start = 10)
fg = folium.FeatureGroup(name = '서울지진해일대피소')
for lat, lon, name in zip(shelter_incheon['위도'], shelter_incheon['경도'], shelter_incheon['지진해일대피소명']):
    fg.add_child(folium.Marker(location=[lat, lon], popup=(folium.Popup(name)), icon=folium.Icon(icon = 'star', color= 'blue', icon_color = 'white')))
map.add_child(fg) 
map.save(outfile='서울.html')

# %% [markdown]
# ## 인천광역시 지도

# %%
shelter_incheon = shelter_G[shelter_G['area']=='인천광역시']
map = folium.Map(location=[37.4644673, 126.534265], zoom_start = 9)
fg = folium.FeatureGroup(name = '인천지진해일대피소')
for lat, lon, name in zip(shelter_incheon['위도'], shelter_incheon['경도'], shelter_incheon['지진해일대피소명']):
    fg.add_child(folium.Marker(location=[lat, lon], popup=(folium.Popup(name)), icon=folium.Icon(icon = 'star', color= 'blue', icon_color = 'white')))
map.add_child(fg) 
map.save(outfile='인천.html')

# %% [markdown]
# ## 경기도 지도

# %%
shelter_ggi = shelter_G[shelter_G['area']=='경기도']
map = folium.Map(location=[37.5969947, 126.5354559], zoom_start = 9)
fg = folium.FeatureGroup(name = '경기지진해일대피소')
for lat, lon, name in zip(shelter_ggi['위도'], shelter_ggi['경도'], shelter_ggi['지진해일대피소명']):
    fg.add_child(folium.Marker(location=[lat, lon], popup=(folium.Popup(name)), icon=folium.Icon(icon = 'star', color= 'blue', icon_color = 'white')))
map.add_child(fg) 
map.save(outfile='경기.html')

# %% [markdown]
# ## 8. 지역별 인구수 대비 최대수용가능 인원수 비교

# %% [markdown]
# - 서울, 인천: 구 단위
# - 경기도: 시 단위
# - (인구 통계가 위와 같은 단위로 분리되어있기 때문)

# %% [markdown]
# ### 과정
# 1. KOSIS에서 서울, 인천, 경기도 인구 통계 불러옴
#
# 2. 서울특별시, 인천광역시, 경기도 행 제거 (각 구 또는 시 인구 수의 합)
#
# 3. 서울 중구, 인천 중구 합쳐지는 문제 발생
#     - 인구 통계 테이블을 각 지역별로 분리하여 따로 저장
#     - 구 또는 시 이름 앞 '서울특별시', '인천광역시', '경기도' 붙여줌
#     - 다시 하나의 테이블로 합침
#
# 4. 인구 통계 테이블의 지역명과 대피소 테이블의 '제공기관명'과 분류가 동일해 '제공기관명'을 기준으로 LEFT JOIN
#     - 인구 통계 테이블에는 있지만 대피소 테이블에는 없는 지역 (=대피소 데이터가 없는 지역) 찾음
#     - 공공데이터 포털에 데이터 요청
#     - 국민재난안전포털에서 데이터 긁어옴
#
# 5. 제공기관명(지역명)으로 groupby한 후, 최대수용인원수를 sum 해서 지역별 최대수용인원수 컬럼 생성
#
# 6. '지역 인구수 - 지역 최대수용인원수'를 'diff'컬럼에 저장
#
# 7. diff가 마이너스면 '불충분', 플러스면 '충분'으로 지정

# %% [markdown]
# ### 데이터 없는 지역
# - 서울특별시 용산구 (곧 받을 예정)
# - 서울특별시 성동구
# - 서울특별시 동대문구 (O)
# - 서울특별시 성북구(O)
# - 서울특별시 도봉구
# - 서울특별시 마포구
# - 서울특별시 구로구
# - 서울특별시 강동구
# - 서울특별시 강북구
# - 경기도 용인시
# - 경기도 안양시
# - 경기도 연천군

# %%
ppl = pd.read_csv('population.csv', encoding = "CP949")

# http://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=DT_1B040A3

# %%
ppl.head()
# Out:
#    행정구역(시군구)별  2019. 09
# 0  행정구역(시군구)별  총인구수 (명)
# 1       서울특별시   9740398
# 2         종로구    151767
# 3          중구    126409
# 4         용산구    228830

# %%
len(ppl)
# Out:
# 87

# %%
ppl[(ppl['행정구역(시군구)별']=='행정구역(시군구)별')|(ppl['행정구역(시군구)별']=='서울특별시')|(ppl['행정구역(시군구)별']=='인천광역시')|(ppl['행정구역(시군구)별']=='경기도')]
# Out:
#     행정구역(시군구)별  2019. 09
# 0   행정구역(시군구)별  총인구수 (명)
# 1        서울특별시   9740398
# 27       인천광역시   2956804
# 38         경기도  13207219

# %%
ppl = ppl.drop([ppl.index[0], ppl.index[1], ppl.index[27], ppl.index[38]])

# %%
ppl
# Out:
#    행정구역(시군구)별 2019. 09
# 2         종로구   151767
# 3          중구   126409
# 4         용산구   228830
# 5         성동구   303158
# 6         광진구   352692
# ..        ...      ...
# 82        포천시   148800
# 83        여주시   110994
# 84        연천군    43933
# 85        가평군    62743
# 86        양평군   117010
#
# [83 rows x 2 columns]

# %%
# 분석 쉽도로 컬럼명 변경 
ppl = ppl.rename(columns={'행정구역(시군구)별': 'sigungu', '2019. 09': 'nop'}) #nop: number of people

# %%
#.iloc으로 [25번째 열까지, 모든 컬럼] 잘라내서 '서울' 테이블로 지정 
서울 = ppl.iloc[:25, :].copy()

# %%
# 서울 구 이름 앞에 서울특별시 붙여넣기
서울['sigungu'] = '서울특별시' + ' ' + 서울.sigungu.str[0:] #future warning 무시 -> 해결방법을 찾아야하지만....ㅎ

# %%
서울
# Out:
#        sigungu     nop
# 2    서울특별시 종로구  151767
# 3     서울특별시 중구  126409
# 4    서울특별시 용산구  228830
# 5    서울특별시 성동구  303158
# 6    서울특별시 광진구  352692
# 7   서울특별시 동대문구  346551
# 8    서울특별시 중랑구  398812
# 9    서울특별시 성북구  441590
# 10   서울특별시 강북구  314090
# 11   서울특별시 도봉구  335280
# 12   서울특별시 노원구  535282
# 13   서울특별시 은평구  481663
# 14  서울특별시 서대문구  310069
# 15   서울특별시 마포구  373629
# 16   서울특별시 양천구  459849
# 17   서울특별시 강서구  593708
# 18   서울특별시 구로구  406748
# 19   서울특별시 금천구  233371
# 20  서울특별시 영등포구  368402
# 21   서울특별시 동작구  397618
# 22   서울특별시 관악구  502117
# 23   서울특별시 서초구  431027
# 24   서울특별시 강남구  544028
# 25   서울특별시 송파구  677489
# 26   서울특별시 강동구  426219

# %%
인천 = ppl.iloc[25:35, :]

# %%
인천['sigungu'] = '인천광역시' + ' ' + 인천.sigungu.str[0:]
# Out:
# c:\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
인천
# Out:
#        sigungu     nop
# 28    인천광역시 중구  132052
# 29    인천광역시 동구   64718
# 30  인천광역시 미추홀구  410998
# 31   인천광역시 연수구  362254
# 32   인천광역시 남동구  533560
# 33   인천광역시 부평구  514856
# 34   인천광역시 계양구  305394
# 35    인천광역시 서구  543108
# 36   인천광역시 강화군   69138
# 37   인천광역시 옹진군   20726

# %%
경기도 = ppl.iloc[35:, :]   #.drop(ppl.index[35:42]).drop(ppl.index[43:45]).drop(ppl.index[49:54]).drop(ppl.index[62:65])

# %%
경기도['sigungu'] = '경기도' + ' ' + 경기도.sigungu.str[0:]
# Out:
# c:\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
경기도
# Out:
#      sigungu      nop
# 39   경기도 수원시  1196074
# 40   경기도 장안구   279819
# 41   경기도 권선구   372825
# 42   경기도 팔달구   177063
# 43   경기도 영통구   366367
# 44   경기도 성남시   944741
# 45   경기도 수정구   234570
# 46   경기도 중원구   221234
# 47   경기도 분당구   488937
# 48  경기도 의정부시   451846
# 49   경기도 안양시   570544
# 50   경기도 만안구   246807
# 51   경기도 동안구   323737
# 52   경기도 부천시   833218
# 53   경기도 광명시   319205
# 54   경기도 평택시   507621
# 55  경기도 동두천시    94912
# 56   경기도 안산시   654668
# 57   경기도 상록구   347662
# 58   경기도 단원구   307006
# 59   경기도 고양시  1059340
# 60   경기도 덕양구   462139
# 61  경기도 일산동구   294668
# 62  경기도 일산서구   302533
# 63   경기도 과천시    58043
# 64   경기도 구리시   199595
# 65  경기도 남양주시   699326
# 66   경기도 오산시   222981
# 67   경기도 시흥시   468274
# 68   경기도 군포시   274667
# 69   경기도 의왕시   159911
# 70   경기도 하남시   269539
# 71   경기도 용인시  1055516
# 72   경기도 처인구   255900
# 73   경기도 기흥구   434472
# 74   경기도 수지구   365144
# 75   경기도 파주시   453825
# 76   경기도 이천시   216225
# 77   경기도 안성시   184082
# 78   경기도 김포시   434344
# 79   경기도 화성시   803252
# 80   경기도 광주시   370411
# 81   경기도 양주시   221579
# 82   경기도 포천시   148800
# 83   경기도 여주시   110994
# 84   경기도 연천군    43933
# 85   경기도 가평군    62743
# 86   경기도 양평군   117010

# %%
# 수원 = ppl.iloc[35:39, :]
# 수원['sigungu'] = '경기도' + ' ' + '수원시'+' ' + 수원.sigungu.str[0:]

# %%
# 성남 = ppl.iloc[39:42, :]
# 성남['sigungu'] = '경기도' + ' ' + '성남시'+' ' + 성남.sigungu.str[0:]

# %%
# 안양 = ppl.iloc[43:45, :]
# 안양['sigungu'] = '경기도' + ' ' + '안양시'+' ' + 안양.sigungu.str[0:]

# %%
# 안산 = ppl.iloc[49:51, :]
# 안산['sigungu'] = '경기도' + ' ' + '안산시'+' ' + 안산.sigungu.str[0:]

# %%
# 고양 = ppl.iloc[51:54, :]
# 고양['sigungu'] = '경기도' + ' ' + '고양시'+' ' + 고양.sigungu.str[0:]

# %%
# 용인 = ppl.iloc[62:65, :]
# 용인['sigungu'] = '경기도' + ' ' + '용인시'+' ' + 용인.sigungu.str[0:]

# %%
ppl_final = pd.concat([서울, 인천, 경기도], ignore_index=True)

# %%
len(ppl_final)
# Out:
# 83

# %%
# 제공기관명이 시이름 + 구이름 으로 되어 있어서 이 컬럼을 기준으로 join 할 예정
shelter_G.제공기관명.unique()
# Out:
# array(['서울특별시 종로구', '경기도 시흥시', '인천광역시 동구', '서울특별시 중랑구', '인천광역시 계양구',
#        '서울특별시 동작구', '경기도 가평군', '경기도 양평군', '경기도 김포시', '경기도 오산시',
#        '경기도 의정부시', '인천광역시 부평구', '서울특별시 영등포구', '인천광역시 옹진군', '경기도 양주시',
#        '경기도 구리시', '경기도 과천시', '서울특별시 송파구', '서울특별시 강서구', '서울특별시 은평구',
#        '경기도 의왕시', '인천광역시 중구', '서울특별시 관악구', '경기도 동두천시', '서울특별시 중구',
#        '경기도 포천시', '서울특별시 금천구', '경기도 남양주시', '경기도 고양시', '서울특별시 광진구',
#        '서울특별시 서대문구', '경기도 화성시', '서울특별시 서초구', '경기도 군포시', '경기도 성남시',
#        '경기도 부천시', '인천광역시 연수구', '경기도 여주시', '서울특별시 노원구', '경기도 안성시',
#        '경기도 파주시', '경기도 안산시', '경기도 이천시', '서울특별시 강남구', '경기도 평택시',
#        '인천광역시 서구', '서울특별시 양천구', '경기도 수원시', '경기도 광주시', '경기도 하남시',
#        '인천광역시 남동구', '인천광역시 미추홀구', '경기도 광명시', '서울특별시 동대문구', '서울특별시 성북구'],
#       dtype=object)

# %%
# 인구테이블과 join하기 위해 필요한 두개 컬럼만 shelter_ppl이라는 테이블로 저장
shelter_ppl = shelter_G[['최대수용인원수', '제공기관명']]

# %%
# 제공기관명으로 groupby해서 그 지역 내 모든 대피소 최대수용인원수 더하기
shelter_capacity_temp= pd.DataFrame(shelter_ppl.groupby('제공기관명')['최대수용인원수'].sum())

# %%
shelter_capacity_temp
# Out:
#               최대수용인원수
# 제공기관명
# 경기도 가평군       24315.0
# 경기도 고양시      125398.0
# 경기도 과천시       86889.0
# 경기도 광명시      744810.0
# 경기도 광주시      232907.0
# 경기도 구리시        4533.0
# 경기도 군포시      192551.0
# 경기도 김포시      555246.0
# 경기도 남양주시      20926.0
# 경기도 동두천시      29709.0
# 경기도 부천시       25845.0
# 경기도 성남시       12241.0
# 경기도 수원시      475265.0
# 경기도 시흥시      393355.0
# 경기도 안산시      738798.0
# 경기도 안성시      282522.0
# 경기도 양주시      503163.0
# 경기도 양평군      256268.0
# 경기도 여주시       15600.0
# 경기도 오산시      179706.0
# 경기도 의왕시      243768.0
# 경기도 의정부시     322569.0
# 경기도 이천시      253540.0
# 경기도 파주시      344659.0
# 경기도 평택시       44908.0
# 경기도 포천시       76695.0
# 경기도 하남시        2540.0
# 경기도 화성시       96832.0
# 서울특별시 강남구    364545.0
# 서울특별시 강서구     83453.0
# 서울특별시 관악구    148573.0
# 서울특별시 광진구     61280.0
# 서울특별시 금천구     28933.0
# 서울특별시 노원구    356852.0
# 서울특별시 동대문구   205109.0
# 서울특별시 동작구    372244.0
# 서울특별시 서대문구   223872.0
# 서울특별시 서초구    127686.0
# 서울특별시 성북구    243093.0
# 서울특별시 송파구    403281.0
# 서울특별시 양천구    167576.0
# 서울특별시 영등포구   629726.0
# 서울특별시 은평구    138487.0
# 서울특별시 종로구    270379.0
# 서울특별시 중구     116900.0
# 서울특별시 중랑구     40856.0
# 인천광역시 계양구    425611.0
# 인천광역시 남동구    409461.0
# 인천광역시 동구      32783.0
# 인천광역시 미추홀구   211630.0
# 인천광역시 부평구    713997.0
# 인천광역시 서구      60162.0
# 인천광역시 연수구    847760.0
# 인천광역시 옹진군     12681.0
# 인천광역시 중구    1307513.0

# %%
find_missing_area = ppl_final.merge(shelter_capacity_temp, how='left', left_on=['sigungu'], right_on=['제공기관명'])

# %%
find_missing_area[find_missing_area['최대수용인원수'].isnull()] #뭐죠? 왜죠? 왜 없죠?
# Out:
#       sigungu      nop  최대수용인원수
# 2   서울특별시 용산구   228830      NaN
# 3   서울특별시 성동구   303158      NaN
# 8   서울특별시 강북구   314090      NaN
# 9   서울특별시 도봉구   335280      NaN
# 13  서울특별시 마포구   373629      NaN
# 16  서울특별시 구로구   406748      NaN
# 24  서울특별시 강동구   426219      NaN
# 33  인천광역시 강화군    69138      NaN
# 36    경기도 장안구   279819      NaN
# 37    경기도 권선구   372825      NaN
# 38    경기도 팔달구   177063      NaN
# 39    경기도 영통구   366367      NaN
# 41    경기도 수정구   234570      NaN
# 42    경기도 중원구   221234      NaN
# 43    경기도 분당구   488937      NaN
# 45    경기도 안양시   570544      NaN
# 46    경기도 만안구   246807      NaN
# 47    경기도 동안구   323737      NaN
# 53    경기도 상록구   347662      NaN
# 54    경기도 단원구   307006      NaN
# 56    경기도 덕양구   462139      NaN
# 57   경기도 일산동구   294668      NaN
# 58   경기도 일산서구   302533      NaN
# 67    경기도 용인시  1055516      NaN
# 68    경기도 처인구   255900      NaN
# 69    경기도 기흥구   434472      NaN
# 70    경기도 수지구   365144      NaN
# 80    경기도 연천군    43933      NaN

# %%
shelter_G[shelter_G['제공기관명'] == '인천광역시 남동구']
# Out:
#       Unnamed: 0      지진해일대피소명 지진해일대피소구분 지진해일대피소유형 지진해일대피소유형구분  \
# 3041        9719    구월초등학교 운동장     지진대피소     옥외대피소         운동장
# 3042        9720    만월초등학교 운동장     지진대피소     옥외대피소         운동장
# 3043        9721   성리초등학교  운동장     지진대피소     옥외대피소         운동장
# 3044        9722        구월근린공원     지진대피소     옥외대피소          공원
# 3045        9723    간석초등학교 운동장     지진대피소     옥외대피소         운동장
# ...          ...           ...       ...       ...         ...
# 3111        9789        장도초등학교     지진대피소     실내대피소          학교
# 3112        9790        논곡초등학교     지진대피소     실내대피소          학교
# 3113        9791        동방초등학교     지진대피소     실내대피소          학교
# 3114        9792  남동문화원(소래아트홀)     지진대피소     실내대피소          기타
# 3115        9793        고잔감리교회     지진대피소     실내대피소          기타
#
#                           소재지도로명주소 소재지지번주소         위도          경도   수용가능면적  \
# 3041   인천광역시 남동구 인주대로721번길 49(구월동)     NaN  37.451896  126.716762   2422.0
# 3042        인천광역시 남동구 선수촌로 28(구월동)     NaN  37.441988  126.715346   3544.0
# 3043      인천광역시 남동구 성리로 32-2 (구월동)     NaN  37.445641  126.710020   6540.0
# 3044        인천광역시 남동구 구월로 251(구월동)     NaN  37.458350  126.718961  17000.0
# 3045    인천광역시 남동구 석산로208번길 37(구월동)     NaN  37.458885  126.716077   6500.0
# ...                            ...     ...        ...         ...      ...
# 3111        인천광역시 남동구 포구로 112(논현동)     NaN  37.407930  126.733607    652.0
# 3112       인천광역시 남동구 함박뫼로 429(논현동)     NaN  37.410391  126.710299    623.0
# 3113        인천광역시 남동구 논현역로 31(논현동)     NaN  37.403153  126.719680    680.0
# 3114  인천광역시 남동구 아암대로1437번길 32(논현동)     NaN  37.392263  126.715045    525.0
# 3115   인천광역시 남동구 앵고개로697번길 41(고잔동)     NaN  37.390993  126.714932    572.0
#
#       ...       관리기관명      관리기관전화번호     데이터기준일자     제공기관코드      제공기관명  \
# 3041  ...  인천광역시 남동구청  032-453-2330  2018-12-04  3530000.0  인천광역시 남동구
# 3042  ...  인천광역시 남동구청  032-453-2330  2018-12-04  3530000.0  인천광역시 남동구
# 3043  ...  인천광역시 남동구청  032-453-2330  2018-12-04  3530000.0  인천광역시 남동구
# 3044  ...  인천광역시 남동구청  032-453-2330  2018-12-04  3530000.0  인천광역시 남동구
# 3045  ...  인천광역시 남동구청  032-453-2330  2018-12-04  3530000.0  인천광역시 남동구
# ...   ...         ...           ...         ...        ...        ...
# 3111  ...  인천광역시 남동구청  032-453-2330  2018-12-04  3530000.0  인천광역시 남동구
# 3112  ...  인천광역시 남동구청  032-453-2330  2018-12-04  3530000.0  인천광역시 남동구
# 3113  ...  인천광역시 남동구청  032-453-2330  2018-12-04  3530000.0  인천광역시 남동구
# 3114  ...  인천광역시 남동구청  032-453-2330  2018-12-04  3530000.0  인천광역시 남동구
# 3115  ...  인천광역시 남동구청  032-453-2330  2018-12-04  3530000.0  인천광역시 남동구
#
#       Unnamed: 29  Unnamed: 0.1   area   위   경
# 3041          NaN           NaN  인천광역시 NaN NaN
# 3042          NaN           NaN  인천광역시 NaN NaN
# 3043          NaN           NaN  인천광역시 NaN NaN
# 3044          NaN           NaN  인천광역시 NaN NaN
# 3045          NaN           NaN  인천광역시 NaN NaN
# ...           ...           ...    ...  ..  ..
# 3111          NaN           NaN  인천광역시 NaN NaN
# 3112          NaN           NaN  인천광역시 NaN NaN
# 3113          NaN           NaN  인천광역시 NaN NaN
# 3114          NaN           NaN  인천광역시 NaN NaN
# 3115          NaN           NaN  인천광역시 NaN NaN
#
# [75 rows x 35 columns]

# %%
shelter_G[shelter_G['소재지도로명주소'].str[0:9]=='인천광역시 남동구']
# Out:
#       Unnamed: 0      지진해일대피소명 지진해일대피소구분 지진해일대피소유형 지진해일대피소유형구분  \
# 3041        9719    구월초등학교 운동장     지진대피소     옥외대피소         운동장
# 3042        9720    만월초등학교 운동장     지진대피소     옥외대피소         운동장
# 3043        9721   성리초등학교  운동장     지진대피소     옥외대피소         운동장
# 3044        9722        구월근린공원     지진대피소     옥외대피소          공원
# 3045        9723    간석초등학교 운동장     지진대피소     옥외대피소         운동장
# ...          ...           ...       ...       ...         ...
# 3111        9789        장도초등학교     지진대피소     실내대피소          학교
# 3112        9790        논곡초등학교     지진대피소     실내대피소          학교
# 3113        9791        동방초등학교     지진대피소     실내대피소          학교
# 3114        9792  남동문화원(소래아트홀)     지진대피소     실내대피소          기타
# 3115        9793        고잔감리교회     지진대피소     실내대피소          기타
#
#                           소재지도로명주소 소재지지번주소         위도          경도   수용가능면적  \
# 3041   인천광역시 남동구 인주대로721번길 49(구월동)     NaN  37.451896  126.716762   2422.0
# 3042        인천광역시 남동구 선수촌로 28(구월동)     NaN  37.441988  126.715346   3544.0
# 3043      인천광역시 남동구 성리로 32-2 (구월동)     NaN  37.445641  126.710020   6540.0
# 3044        인천광역시 남동구 구월로 251(구월동)     NaN  37.458350  126.718961  17000.0
# 3045    인천광역시 남동구 석산로208번길 37(구월동)     NaN  37.458885  126.716077   6500.0
# ...                            ...     ...        ...         ...      ...
# 3111        인천광역시 남동구 포구로 112(논현동)     NaN  37.407930  126.733607    652.0
# 3112       인천광역시 남동구 함박뫼로 429(논현동)     NaN  37.410391  126.710299    623.0
# 3113        인천광역시 남동구 논현역로 31(논현동)     NaN  37.403153  126.719680    680.0
# 3114  인천광역시 남동구 아암대로1437번길 32(논현동)     NaN  37.392263  126.715045    525.0
# 3115   인천광역시 남동구 앵고개로697번길 41(고잔동)     NaN  37.390993  126.714932    572.0
#
#       ...       관리기관명      관리기관전화번호     데이터기준일자     제공기관코드      제공기관명  \
# 3041  ...  인천광역시 남동구청  032-453-2330  2018-12-04  3530000.0  인천광역시 남동구
# 3042  ...  인천광역시 남동구청  032-453-2330  2018-12-04  3530000.0  인천광역시 남동구
# 3043  ...  인천광역시 남동구청  032-453-2330  2018-12-04  3530000.0  인천광역시 남동구
# 3044  ...  인천광역시 남동구청  032-453-2330  2018-12-04  3530000.0  인천광역시 남동구
# 3045  ...  인천광역시 남동구청  032-453-2330  2018-12-04  3530000.0  인천광역시 남동구
# ...   ...         ...           ...         ...        ...        ...
# 3111  ...  인천광역시 남동구청  032-453-2330  2018-12-04  3530000.0  인천광역시 남동구
# 3112  ...  인천광역시 남동구청  032-453-2330  2018-12-04  3530000.0  인천광역시 남동구
# 3113  ...  인천광역시 남동구청  032-453-2330  2018-12-04  3530000.0  인천광역시 남동구
# 3114  ...  인천광역시 남동구청  032-453-2330  2018-12-04  3530000.0  인천광역시 남동구
# 3115  ...  인천광역시 남동구청  032-453-2330  2018-12-04  3530000.0  인천광역시 남동구
#
#       Unnamed: 29  Unnamed: 0.1   area   위   경
# 3041          NaN           NaN  인천광역시 NaN NaN
# 3042          NaN           NaN  인천광역시 NaN NaN
# 3043          NaN           NaN  인천광역시 NaN NaN
# 3044          NaN           NaN  인천광역시 NaN NaN
# 3045          NaN           NaN  인천광역시 NaN NaN
# ...           ...           ...    ...  ..  ..
# 3111          NaN           NaN  인천광역시 NaN NaN
# 3112          NaN           NaN  인천광역시 NaN NaN
# 3113          NaN           NaN  인천광역시 NaN NaN
# 3114          NaN           NaN  인천광역시 NaN NaN
# 3115          NaN           NaN  인천광역시 NaN NaN
#
# [75 rows x 35 columns]

# %%
# join 하기
shelter_capacity = shelter_capacity_temp.merge(ppl_final, how='left', left_on=['제공기관명'], right_on=['sigungu'])

# %%
shelter_capacity
# Out:
#       최대수용인원수     sigungu      nop
# 0     24315.0     경기도 가평군    62743
# 1    125398.0     경기도 고양시  1059340
# 2     86889.0     경기도 과천시    58043
# 3    744810.0     경기도 광명시   319205
# 4    232907.0     경기도 광주시   370411
# 5      4533.0     경기도 구리시   199595
# 6    192551.0     경기도 군포시   274667
# 7    555246.0     경기도 김포시   434344
# 8     20926.0    경기도 남양주시   699326
# 9     29709.0    경기도 동두천시    94912
# 10    25845.0     경기도 부천시   833218
# 11    12241.0     경기도 성남시   944741
# 12   475265.0     경기도 수원시  1196074
# 13   393355.0     경기도 시흥시   468274
# 14   738798.0     경기도 안산시   654668
# 15   282522.0     경기도 안성시   184082
# 16   503163.0     경기도 양주시   221579
# 17   256268.0     경기도 양평군   117010
# 18    15600.0     경기도 여주시   110994
# 19   179706.0     경기도 오산시   222981
# 20   243768.0     경기도 의왕시   159911
# 21   322569.0    경기도 의정부시   451846
# 22   253540.0     경기도 이천시   216225
# 23   344659.0     경기도 파주시   453825
# 24    44908.0     경기도 평택시   507621
# 25    76695.0     경기도 포천시   148800
# 26     2540.0     경기도 하남시   269539
# 27    96832.0     경기도 화성시   803252
# 28   364545.0   서울특별시 강남구   544028
# 29    83453.0   서울특별시 강서구   593708
# 30   148573.0   서울특별시 관악구   502117
# 31    61280.0   서울특별시 광진구   352692
# 32    28933.0   서울특별시 금천구   233371
# 33   356852.0   서울특별시 노원구   535282
# 34   205109.0  서울특별시 동대문구   346551
# 35   372244.0   서울특별시 동작구   397618
# 36   223872.0  서울특별시 서대문구   310069
# 37   127686.0   서울특별시 서초구   431027
# 38   243093.0   서울특별시 성북구   441590
# 39   403281.0   서울특별시 송파구   677489
# 40   167576.0   서울특별시 양천구   459849
# 41   629726.0  서울특별시 영등포구   368402
# 42   138487.0   서울특별시 은평구   481663
# 43   270379.0   서울특별시 종로구   151767
# 44   116900.0    서울특별시 중구   126409
# 45    40856.0   서울특별시 중랑구   398812
# 46   425611.0   인천광역시 계양구   305394
# 47   409461.0   인천광역시 남동구   533560
# 48    32783.0    인천광역시 동구    64718
# 49   211630.0  인천광역시 미추홀구   410998
# 50   713997.0   인천광역시 부평구   514856
# 51    60162.0    인천광역시 서구   543108
# 52   847760.0   인천광역시 연수구   362254
# 53    12681.0   인천광역시 옹진군    20726
# 54  1307513.0    인천광역시 중구   132052

# %%
shelter_capacity.columns
# Out:
# Index(['최대수용인원수', 'sigungu', 'nop'], dtype='object')

# %%
shelter_capacity.sample(10)
# Out:
#      최대수용인원수    sigungu      nop
# 33  356852.0  서울특별시 노원구   535282
# 31   61280.0  서울특별시 광진구   352692
# 18   15600.0    경기도 여주시   110994
# 21  322569.0   경기도 의정부시   451846
# 43  270379.0  서울특별시 종로구   151767
# 47  409461.0  인천광역시 남동구   533560
# 1   125398.0    경기도 고양시  1059340
# 22  253540.0    경기도 이천시   216225
# 4   232907.0    경기도 광주시   370411
# 50  713997.0  인천광역시 부평구   514856

# %%
# 분석 용이하게 하기 위해 컬럼명 변경 
shelter_capacity.rename(columns={'최대수용인원수':'max'}, inplace=True)

# %%
len(shelter_capacity)
# Out:
# 55

# %%
# max 컬럼이 float64이기때문에 정확한 비교를 위해 타입 변경
shelter_capacity['nop'] = shelter_capacity['nop'].astype('float64')

# %%
shelter_capacity[shelter_capacity['nop']>shelter_capacity['max']]
# Out:
#          max     sigungu        nop
# 0    24315.0     경기도 가평군    62743.0
# 1   125398.0     경기도 고양시  1059340.0
# 4   232907.0     경기도 광주시   370411.0
# 5     4533.0     경기도 구리시   199595.0
# 6   192551.0     경기도 군포시   274667.0
# 8    20926.0    경기도 남양주시   699326.0
# 9    29709.0    경기도 동두천시    94912.0
# 10   25845.0     경기도 부천시   833218.0
# 11   12241.0     경기도 성남시   944741.0
# 12  475265.0     경기도 수원시  1196074.0
# 13  393355.0     경기도 시흥시   468274.0
# 18   15600.0     경기도 여주시   110994.0
# 19  179706.0     경기도 오산시   222981.0
# 21  322569.0    경기도 의정부시   451846.0
# 23  344659.0     경기도 파주시   453825.0
# 24   44908.0     경기도 평택시   507621.0
# 25   76695.0     경기도 포천시   148800.0
# 26    2540.0     경기도 하남시   269539.0
# 27   96832.0     경기도 화성시   803252.0
# 28  364545.0   서울특별시 강남구   544028.0
# 29   83453.0   서울특별시 강서구   593708.0
# 30  148573.0   서울특별시 관악구   502117.0
# 31   61280.0   서울특별시 광진구   352692.0
# 32   28933.0   서울특별시 금천구   233371.0
# 33  356852.0   서울특별시 노원구   535282.0
# 34  205109.0  서울특별시 동대문구   346551.0
# 35  372244.0   서울특별시 동작구   397618.0
# 36  223872.0  서울특별시 서대문구   310069.0
# 37  127686.0   서울특별시 서초구   431027.0
# 38  243093.0   서울특별시 성북구   441590.0
# 39  403281.0   서울특별시 송파구   677489.0
# 40  167576.0   서울특별시 양천구   459849.0
# 42  138487.0   서울특별시 은평구   481663.0
# 44  116900.0    서울특별시 중구   126409.0
# 45   40856.0   서울특별시 중랑구   398812.0
# 47  409461.0   인천광역시 남동구   533560.0
# 48   32783.0    인천광역시 동구    64718.0
# 49  211630.0  인천광역시 미추홀구   410998.0
# 51   60162.0    인천광역시 서구   543108.0
# 53   12681.0   인천광역시 옹진군    20726.0

# %%
# 두 컬럼의 차를 diff 컬럼에 저장
shelter_capacity['diff'] = shelter_capacity['max']-shelter_capacity['nop']

# %%
shelter_capacity['diff'].max()
# Out:
# 1175461.0

# %%
shelter_capacity['diff'].min()
# Out:
# -933942.0

# %%
shelter_capacity[shelter_capacity['diff']==shelter_capacity['diff'].max()]
# Out:
#           max   sigungu       nop       diff
# 54  1307513.0  인천광역시 중구  132052.0  1175461.0

# %%
shelter_capacity[shelter_capacity['sigungu'] =='인천광역시 중구']
# Out:
#           max   sigungu       nop       diff
# 54  1307513.0  인천광역시 중구  132052.0  1175461.0

# %%
# 값이 마이너스면 불충분, 플러스면 충분으로 지정
shelter_capacity['capacity'] = shelter_capacity['diff'].apply(lambda x: '불충분' if x<0 else '충분' )

# %%
len(shelter_capacity[shelter_capacity['nop']>shelter_capacity['max']])
# Out:
# 40

# %%
shelter_capacity[shelter_capacity['nop']==shelter_capacity['nop'].max()]
# Out:
#          max  sigungu        nop      diff capacity
# 12  475265.0  경기도 수원시  1196074.0 -720809.0      불충분

# %%
shelter_capacity.sort_values('nop', ascending = False).head(5)
# Out:
#          max  sigungu        nop      diff capacity
# 12  475265.0  경기도 수원시  1196074.0 -720809.0      불충분
# 1   125398.0  경기도 고양시  1059340.0 -933942.0      불충분
# 11   12241.0  경기도 성남시   944741.0 -932500.0      불충분
# 10   25845.0  경기도 부천시   833218.0 -807373.0      불충분
# 27   96832.0  경기도 화성시   803252.0 -706420.0      불충분

# %%
# 인천 중구의 최대수용인원이 이상하게 많은 이유는 주차장이 많고 면적이 넓은 인천공항과 항구가 있기 때문
shelter_capacity.sort_values('max', ascending = False).head(5)
# Out:
#           max    sigungu       nop       diff capacity
# 54  1307513.0   인천광역시 중구  132052.0  1175461.0       충분
# 52   847760.0  인천광역시 연수구  362254.0   485506.0       충분
# 3    744810.0    경기도 광명시  319205.0   425605.0       충분
# 14   738798.0    경기도 안산시  654668.0    84130.0       충분
# 50   713997.0  인천광역시 부평구  514856.0   199141.0       충분

# %%
shelter_G[shelter_G['제공기관명']=='인천광역시 중구'].sort_values('최대수용인원수', ascending = False)
# Out:
#       Unnamed: 0                  지진해일대피소명 지진해일대피소구분 지진해일대피소유형 지진해일대피소유형구분  \
# 1206        4597    인천국제공항 제1국제여객터미널 장기주차장     지진대피소     옥외대피소          기타
# 1208        4599      인천국제공항 제2여객터미널 장기주차장     지진대피소     옥외대피소          기타
# 1203        4594               공항합동청사 잔디광장     지진대피소     옥외대피소          기타
# 1198        4589                  영종하늘체육공원     지진대피소     옥외대피소          공원
# 1181        4572                      자유공원     지진대피소     옥외대피소          공원
# 1201        4592                     영마루공원     지진대피소     옥외대피소          공원
# 1202        4593                     유수지공원     지진대피소     옥외대피소          공원
# 1220        4611                      을왕공원     지진대피소     옥외대피소          공원
# 1215        4606                공항합동청사 축구장     지진대피소     옥외대피소         체육관
# 1214        4605      인천국제공항 화물터미널 북측4번주차장     지진대피소     옥외대피소          기타
# 1204        4595       인천국제공항 제2여객터미널 썬큰가든     지진대피소     옥외대피소          기타
# 1212        4603      인천국제공항 화물터미널 남측5번주차장     지진대피소     옥외대피소          기타
# 1179        4570                 연안부두 해양광장     지진대피소     옥외대피소          기타
# 1213        4604      인천국제공항 화물터미널 북측2번주차장     지진대피소     옥외대피소          기타
# 1209        4600  인천국제공항 제2여객터미널 제2합동청사주차장     지진대피소     옥외대피소          기타
# 1210        4601      인천국제공항 화물터미널 남측2번주차장     지진대피소     옥외대피소          기타
# 1191        4582                      율목공원     지진대피소     옥외대피소          공원
# 1196        4587               제물포고등학교 운동장     지진대피소     옥외대피소         운동장
# 1211        4602      인천국제공항 화물터미널 남측4번주차장     지진대피소     옥외대피소          기타
# 1205        4596  인천국제공항 제1국제여객터미널 서측귀빈주차장     지진대피소     옥외대피소          기타
# 1207        4598    인천국제공항 제1여객터미널 동측귀빈주차장     지진대피소     옥외대피소          기타
# 1188        4579                 신흥중학교 운동장     지진대피소     옥외대피소         운동장
# 1187        4578               신흥여자중학교 운동장     지진대피소     옥외대피소         운동장
# 1193        4584                 광성중학교 운동장     지진대피소     옥외대피소         운동장
# 1180        4571              인천연안초등학교 운동장     지진대피소     옥외대피소         운동장
# 1186        4577              인천신흥초등학교 운동장     지진대피소     옥외대피소         운동장
# 1218        4609               인천공항중학교 운동장     지진대피소     옥외대피소         운동장
# 1192        4583                인천정보산업고등학교     지진대피소     옥외대피소         운동장
# 1197        4588                      월미공원     지진대피소     옥외대피소          공원
# 1195        4586              인일여자고등학교 운동장     지진대피소     옥외대피소         운동장
# 1189        4580              인천신광초등학교 운동장     지진대피소     옥외대피소         운동장
# 1216        4607                삼목초등학교 운동장     지진대피소     옥외대피소         운동장
# 1190        4581              인천신선초등학교 운동장     지진대피소     옥외대피소         운동장
# 1219        4610              인천공항초등학교 운동장     지진대피소     옥외대피소         운동장
# 1194        4585                송월초등학교 운동장     지진대피소     옥외대피소         운동장
# 1185        4576                 송도중학교 운동장     지진대피소     옥외대피소         운동장
# 1184        4575                     답동소공원     지진대피소     옥외대피소          공원
# 1222        4613                용유초등학교 운동장     지진대피소     옥외대피소         운동장
# 1221        4612                 용유중학교 운동장     지진대피소     옥외대피소         운동장
# 1182        4573               인성여자중학교 운동장     지진대피소     옥외대피소         운동장
# 1183        4574                인성초등학교 운동장     지진대피소     옥외대피소         운동장
# 1217        4608                운서초등학교 운동장     지진대피소     옥외대피소         운동장
# 1199        4590                영종초등학교 운동장     지진대피소     옥외대피소         운동장
# 1200        4591                운남초등학교 운동장     지진대피소     옥외대피소         운동장
# 1223        4614          용유초등학교 무의분교장 운동장     지진대피소     옥외대피소         운동장
#
#                             소재지도로명주소 소재지지번주소         위도          경도    수용가능면적  \
# 1206           인천광역시 중구 공항로 272(운서동)     NaN  37.484816  126.439616  426400.0
# 1208       인천광역시 중구 제2터미널대로 332(운서동)     NaN  37.482111  126.415732  127500.0
# 1203       인천광역시 중구 공항로424번길 43(운서동)     NaN  37.440212  126.459692   92000.0
# 1198         인천광역시 중구 하늘달빛로 108(중산동)     NaN  37.488172  126.556041   60631.0
# 1181       인천광역시 중구 자유공원남로 25(송학동1가)     NaN  37.474579  126.622667   48097.0
# 1201           인천광역시 중구 영종대로 77(운서동)     NaN  37.495640  126.487541   42081.2
# 1202      인천광역시 중구 신도시북로 31-35 (운서동)     NaN  37.499664  126.480475   41272.7
# 1220                인천광역시 중구 을왕동 산78     NaN  37.270171  126.224321   40572.7
# 1215       인천광역시 중구 공항로424번길 47(운서동)     NaN  37.462461  126.474153   19000.0
# 1214  인천광역시 중구 공항동로295번길 77-11 (운서동)     NaN  37.471204  126.466184   15300.0
# 1204           인천광역시 중구 공항로 272(운서동)     NaN  37.484816  126.439616   14000.0
# 1212            인천광역시 중구 운서동 2842-17     NaN  37.466617  126.474685   13050.0
# 1179         인천광역시 중구 연안부두로 36(항동7가)     NaN  37.454895  126.601284   12506.1
# 1213  인천광역시 중구 공항동로295번길 77-11 (운서동)     NaN  37.471204  126.466184   12150.0
# 1209           인천광역시 중구 공항로 272(운서동)     NaN  37.484816  126.439616   12000.0
# 1210     인천광역시 중구 공항동로193번길 116(운서동)     NaN  37.462123  126.467176   10800.0
# 1191            인천광역시 중구 율목로 36(율목동)     NaN  37.469982  126.633371    9785.0
# 1196        인천광역시 중구 자유공원로 58-9 (전동)     NaN  37.476631  126.623977    7280.0
# 1211     인천광역시 중구 공항동로193번길 116(운서동)     NaN  37.462123  126.467176    6300.0
# 1205           인천광역시 중구 공항로 272(운서동)     NaN  37.484816  126.439616    4200.0
# 1207           인천광역시 중구 공항로 271(운서동)     NaN  37.447549  126.458091    3696.0
# 1188      인천광역시 중구 인항로24번길 38(신흥동3가)     NaN  37.454167  126.629940    3567.2
# 1187      인천광역시 중구 인항로24번길 37(신흥동3가)     NaN  37.454041  126.632101    3186.4
# 1193      인천광역시 중구 참외전로244번길 47(도원동)     NaN  37.467430  126.639963    3178.0
# 1180     인천광역시 중구 연안부두로33번길 53(항동7가)     NaN  37.453758  126.607685    3143.0
# 1186           인천광역시 중구 제물량로 134(답동)     NaN  37.470254  126.628526    3115.0
# 1218       인천광역시 중구 영종대로27번길 49(운서동)     NaN  37.497487  126.484121    3108.0
# 1192          인천광역시 중구 참외전로 192(율목동)     NaN  37.470537  126.636579    2940.0
# 1197      인천광역시 중구 월미로 131-9 (북성동1가)     NaN  37.475963  126.605087    2907.8
# 1195        인천광역시 중구 참외전로72번길 10(전동)     NaN  37.477868  126.626207    2800.0
# 1189          인천광역시 중구 인중로 63(신흥동3가)     NaN  37.464334  126.634510    2730.0
# 1216          인천광역시 중구 신도시북로 42(운서동)     NaN  37.498677  126.486351    2620.8
# 1190    인천광역시 중구 축항대로291번길 33(신흥동3가)     NaN  37.451552  126.627616    2589.3
# 1219          인천광역시 중구 신도시남로 43(운서동)     NaN  37.491895  126.486002    2566.2
# 1194       인천광역시 중구 자유공원로 106-8 (전동)     NaN  37.478483  126.624650    2786.4
# 1185           인천광역시 중구 제물량로 123(답동)     NaN  37.468469  126.629249    2249.8
# 1184                인천광역시 중구 답동 18-5     NaN  37.469516  126.627542    2550.0
# 1222         인천광역시 중구 남북로87번길 4(남북동)     NaN  37.448080  126.412456    2100.0
# 1221         인천광역시 중구 남북로87번길 4(남북동)     NaN  37.448080  126.412456    2100.0
# 1182         인천광역시 중구 홍예문로 39(송학동2가)     NaN  37.474213  126.624387    2100.0
# 1183      인천광역시 중구 신포로39번길 42(송학동2가)     NaN  37.473946  126.624248    2100.0
# 1217           인천광역시 중구 운서2로 57(운서동)     NaN  37.483799  126.512218    2100.0
# 1199         인천광역시 중구 하늘달빛로 133(중산동)     NaN  37.488701  126.553722    2100.0
# 1200           인천광역시 중구 운남서로 38(운남동)     NaN  37.490224  126.530248    2100.0
# 1223      인천광역시 중구 대무의로 302-17 (무의동)     NaN  37.400968  126.417147     840.0
#
#       ...                                관리기관명 관리기관전화번호     데이터기준일자  \
# 1206  ...                             인천국제공항공사      NaN  2019-05-30
# 1208  ...                             인천국제공항공사      NaN  2019-05-30
# 1203  ...                             인천국제공항공사      NaN  2019-05-30
# 1198  ...                 인천광역시 중구 국제도시국 도시공원과      NaN  2019-05-30
# 1181  ...                   인천광역시 중구 총무국 안전관리과      NaN  2019-05-30
# 1201  ...                   인천광역시 중구 총무국 안전관리과      NaN  2019-05-30
# 1202  ...                   인천광역시 중구 총무국 안전관리과      NaN  2019-05-30
# 1220  ...                   인천광역시 중구 총무국 안전관리과      NaN  2019-05-30
# 1215  ...                             인천국제공항공사      NaN  2019-05-30
# 1214  ...                             인천국제공항공사      NaN  2019-05-30
# 1204  ...                             인천국제공항공사      NaN  2019-05-30
# 1212  ...                             인천국제공항공사      NaN  2019-05-30
# 1179  ...                       인천광역시 중구 관광진흥실      NaN  2019-05-30
# 1213  ...                             인천국제공항공사      NaN  2019-05-30
# 1209  ...                             인천국제공항공사      NaN  2019-05-30
# 1210  ...                             인천국제공항공사      NaN  2019-05-30
# 1191  ...                 인천광역시 중구 도시재생국 도시개발과      NaN  2019-05-30
# 1196  ...                     인천광역시교육청 제물포고등학교      NaN  2019-05-30
# 1211  ...                             인천국제공항공사      NaN  2019-05-30
# 1205  ...                             인천국제공항공사      NaN  2019-05-30
# 1207  ...                             인천국제공항공사      NaN  2019-05-30
# 1188  ...          인천광역시교육청 인천광역시남부교육지원청 신흥중학교      NaN  2019-05-30
# 1187  ...        인천광역시교육청 인천광역시남부교육지원청 신흥여자중학교      NaN  2019-05-30
# 1193  ...          인천광역시교육청 인천광역시남부교육지원청 광성중학교      NaN  2019-05-30
# 1180  ...       인천광역시교육청 인천광역시남부교육지원청 인천연안초등학교      NaN  2019-05-30
# 1186  ...       인천광역시교육청 인천광역시남부교육지원청 인천신흥초등학교      NaN  2019-05-30
# 1218  ...        인천광역시교육청 인천광역시남부교육지원청 인천공항중학교      NaN  2019-05-30
# 1192  ...                  인천광역시교육청 인천정보산업고등학교      NaN  2019-05-30
# 1197  ...                   인천광역시 중구 총무국 안전관리과      NaN  2019-05-30
# 1195  ...                    인천광역시교육청 인일여자고등학교      NaN  2019-05-30
# 1189  ...       인천광역시교육청 인천광역시남부교육지원청 인천신광초등학교      NaN  2019-05-30
# 1216  ...       인천광역시교육청 인천광역시남부교육지원청 인천삼목초등학교      NaN  2019-05-30
# 1190  ...       인천광역시교육청 인천광역시남부교육지원청 인천신선초등학교      NaN  2019-05-30
# 1219  ...       인천광역시교육청 인천광역시남부교육지원청 인천공항초등학교      NaN  2019-05-30
# 1194  ...       인천광역시교육청 인천광역시남부교육지원청 인천송월초등학교      NaN  2019-05-30
# 1185  ...          인천광역시교육청 인천광역시남부교육지원청 송도중학교      NaN  2019-05-30
# 1184  ...                 인천광역시 중구 도시관리국 도시개발과      NaN  2019-05-30
# 1222  ...       인천광역시교육청 인천광역시남부교육지원청 인천용유초등학교      NaN  2019-05-30
# 1221  ...          인천광역시교육청 인천광역시남부교육지원청 용유중학교      NaN  2019-05-30
# 1182  ...        인천광역시교육청 인천광역시남부교육지원청 인성여자중학교      NaN  2019-05-30
# 1183  ...         인천광역시교육청 인천광역시남부교육지원청 인성초등학교      NaN  2019-05-30
# 1217  ...       인천광역시교육청 인천광역시남부교육지원청 인천운서초등학교      NaN  2019-05-30
# 1199  ...       인천광역시교육청 인천광역시남부교육지원청 인천영종초등학교      NaN  2019-05-30
# 1200  ...       인천광역시교육청 인천광역시남부교육지원청 인천운남초등학교      NaN  2019-05-30
# 1223  ...  인천광역시교육청 인천광역시남부교육지원청 인천용유초등학교무의분교장      NaN  2019-05-30
#
#          제공기관코드     제공기관명  Unnamed: 29  Unnamed: 0.1   area   위   경
# 1206  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1208  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1203  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1198  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1181  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1201  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1202  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1220  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1215  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1214  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1204  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1212  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1179  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1213  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1209  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1210  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1191  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1196  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1211  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1205  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1207  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1188  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1187  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1193  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1180  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1186  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1218  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1192  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1197  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1195  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1189  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1216  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1190  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1219  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1194  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1185  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1184  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1222  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1221  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1182  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1183  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1217  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1199  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1200  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
# 1223  3490000.0  인천광역시 중구          NaN           NaN  인천광역시 NaN NaN
#
# [45 rows x 35 columns]

# %%
line_chart1 = plt.plot(shelter_capacity['nop'])
line_chart2 = plt.plot(shelter_capacity['max'])
plt.title('인구수 대비 지역내 대피소 최대수용인원')
plt.xlabel('시군')
plt.ylabel('인구수')
plt.legend(['지역인구수', '최대수용인원수'], loc = 1)
plt.show()

# %%
labels=['불충분', '충분']
shelter_capacity['capacity'].value_counts().plot.pie(labels = labels
                    ,colors= ['#98DBC6', '#FFCCBB']
                    ,startangle = 60
                    ,shadow = True
                    ,autopct = '%1.1f%%'
                    ,explode = (0.1,0) 
                    ,figsize=(5, 5)
                    ,fontsize = 15)
plt.title('인구수 대비 지역내 대피소 최대수용인원', fontsize=20)
pylab.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
shelter_capacity['diff'] = shelter_capacity['diff'].astype(int)

# %%
from folium.plugins import HeatMap
map = folium.Map(location=[37.5969947, 126.5354559], zoom_start = 9)

# %%
shelter_capacity.head()
# Out:
#         max  sigungu        nop    diff capacity
# 0   24315.0  경기도 가평군    62743.0  -38428      불충분
# 1  125398.0  경기도 고양시  1059340.0 -933942      불충분
# 2   86889.0  경기도 과천시    58043.0   28846       충분
# 3  744810.0  경기도 광명시   319205.0  425605       충분
# 4  232907.0  경기도 광주시   370411.0 -137504      불충분

# %% [markdown]
# ## 트러블 슈팅
# - 지진해일대피소 데이터가 없는 시, 구가 있다
#     - 공공데이터 포털에 요청
#     - 국민재난안전포탈에서 끌어옴
# - 인천 중구, 서울 중구, 경기도 광주, 광주광역시와 같이 지역명 혼동
#     - 구 이름 앞에 시 이름을 붙여 구분 후 분석
# - API로 위도 경도 결측치 채우기
#     - KAKAO, LacationIQ 둘다 해도 안나오는 데이터 있음
#         - 노가다로 채움
# - 서울, 인천, 경기 각 지역 대피소 수가 많아서 지도가 안돌아감
#     - 방법이 필요
# - 세종시 데이터에는 중복 데이터가 있음
#     - 중복 데이터 확인 후 제거
#     - 중복 이유 문의 예정
# - 주소를 검색해봤는데 밭이 나온다
#     - 미해결

# %% [markdown]
# ### 역할분배
# - 지역별로 나누어 분석중

# %% [markdown]
# ### 앞으로 더 해볼 것 (hopes & dreams)
# - 대피소에서 더 나아가 '행정안전부_이재민임시주거시설정보'데이터를 분석하여 실내대피소와 임시주거시설 비교
# - 인구수 대비 최대수용인원 부족하면 색깔이 진하게 히트맵으로 시각화하여 문제가 심각한 지역 찾기
# - 지진 데이터를 보며 지진이 자주 일어나는 지역을 찾아보고 집중 분석
# - 지진대피소와 지진해일대피소의 구분 등 더 많은 배경지식 조사
# - 구 또는 시 단위가 아닌 동 단위로 인구 수 대비 최대수용가능 인원수 분석
# - 개선 방안 모색
#      - 대피소 불충분 지역에 대피소를 증축한다면 위치 최적화 (입지 분석) -- 현실가능성....?
#      - 현재 위치 기반 최단거리 대피소 추천
#      - 재난 위치에 따른 대피소 추천
# - 10월 18일 마감인 '서울특별시 빅데이터 캠퍼스 공모전' 준비

# %% [markdown]
# ### 동기 & 선미님께 받고 싶은 도움
# - 데이터가 많아서 지도가 안돌아가는데 어떡하나요?
# - 최적 위치 선정을 하고 싶은데 도움이 될만한 강의 또는 글이 있을까요?
# - 데이터가 없는 지역 데이터 요청했는데 이유도 안말해주고 거절당했어요....안전처에서 재난소 위치는 가져올수 있지만 데이터가 많이 부족한데 이거 어떻게 하면 좋을까요?
# - 주소가 잘못된 데이터는 빼는게 좋을까요?
# - 피드백 주세요~~

# %%
# table = pd.read_csv('상권배후지-추정유동인구(2019년).csv', encoding = "CP949")
